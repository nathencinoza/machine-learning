# %% [markdown]
# <a href="https://colab.research.google.com/github/nathencinoza/machine-learning/blob/main/BoxPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('/content/drive/MyDrive/Orga 2/TP3/TP3 dataset music/train.parquet')

# %%
df = df[['track_name', 'genre', 'popularity', 'artist', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence']]
df.head(5)
# Out:
#   track_name  genre  popularity   artist  acousticness  danceability  \
# 0       Halo  Dance          79  Beyoncé        0.2720         0.508
# 1       Halo    Pop          80  Beyoncé        0.2720         0.508
# 2       Halo    R&B          80  Beyoncé        0.2720         0.508
# 3  Partition  Dance          71  Beyoncé        0.0296         0.412
# 4  Partition    Pop          71  Beyoncé        0.0296         0.412
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 1       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 2       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 3       319467   0.441            0.0726   B    0.3060   -11.523  Minor
# 4       319467   0.441            0.0726   B    0.3060   -11.523  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0628   79.983            4/4    0.472
# 1       0.0628   79.983            4/4    0.472
# 2       0.0628   79.983            4/4    0.472
# 3       0.2910  185.571            4/4    0.174
# 4       0.2910  185.571            4/4    0.174

# %%
generos = ['Rock','Alternative','Dance',"Children’s Music",'Pop','Folk','Rap','R&B','Blues','Country','Ska','Hip-Hop','Indie','Soul']
df = df[df['genre'].isin(generos)]

# %%
df = df[df['instrumentalness'] > 0.5]

# %%
df
# Out:
#                   track_name             genre  popularity        artist  \
# 938    Welcome To Heartbreak               Rap          61    Kanye West
# 2018                Promises             Blues          46  Eric Clapton
# 2022           Autumn Leaves             Blues          49  Eric Clapton
# 2040     Motherless Children             Blues          33  Eric Clapton
# 2050              Tulsa Time             Blues          34  Eric Clapton
# ...                      ...               ...         ...           ...
# 33798          Rocket Skates  Children’s Music          46      Deftones
# 33995         Wildest Dreams              Folk          41    Ryan Adams
# 34061                  Words              Folk          47           Low
# 34188                Can Can               Ska          36   Bad Manners
# 34190            Fatty Fatty               Ska          26   Bad Manners
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 938        0.096900         0.667       262933   0.452             0.579   G
# 2018       0.694000         0.553       184933   0.347             0.611   G
# 2022       0.795000         0.549       340787   0.188             0.682   B
# 2040       0.024400         0.559       291040   0.822             0.716   A
# 2050       0.422000         0.709       208933   0.447             0.898   D
# ...             ...           ...          ...     ...               ...  ..
# 33798      0.000002         0.129       254120   0.951             0.880   E
# 33995      0.000171         0.483       321120   0.785             0.536   F
# 34061      0.093100         0.347       348800   0.209             0.617   F
# 34188      0.458000         0.734       170693   0.760             0.741   B
# 34190      0.078900         0.685       145920   0.829             0.589  D#
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 938      0.1110   -10.990  Major       0.0341   95.982            4/4   0.0734
# 2018     0.0947   -18.425  Major       0.0333  154.634            4/4   0.6970
# 2022     0.1100   -17.402  Minor       0.0309   82.745            4/4   0.1980
# 2040     0.3470   -11.761  Major       0.0368  127.852            4/4   0.7350
# 2050     0.0523   -16.793  Major       0.0410  125.105            4/4   0.8560
# ...         ...       ...    ...          ...      ...            ...      ...
# 33798    0.0854    -4.922  Major       0.1170   76.343            4/4   0.2030
# 33995    0.0668    -6.769  Minor       0.0327  119.805            4/4   0.4520
# 34061    0.1030   -15.268  Major       0.0262   80.242            4/4   0.2290
# 34188    0.3620    -7.426  Major       0.0360  157.173            4/4   0.9130
# 34190    0.1150    -7.099  Major       0.0676  147.274            4/4   0.9830
#
# [1085 rows x 17 columns]

# %%
plt.figure(dpi = 125)
sns.boxplot(data=df, x='genre', y='valence', palette=['#00A7E1'], showfliers=False)
plt.xticks(rotation=90)
plt.title("Promedio de positividad de canciones instrumentales \nsegún su género")
plt.xlabel("Género")
plt.ylabel("Positividad")
plt.show()
