# %% [markdown]
# <a href="https://colab.research.google.com/github/nathencinoza/machine-learning/blob/main/BoxPlot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet('/content/drive/MyDrive/Orga 2/TP3/TP3 dataset music/train.parquet')

# %%
generos = ['Rock','Alternative','Dance',"Children’s Music",'Pop','Folk','Rap','R&B','Blues','Country','Ska','Hip-Hop','Indie','Soul']
df = df[df['genre'].isin(generos)]
df = df[['track_name', 'genre', 'popularity', 'artist', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence']]
df.head(5)
# Out:
#   track_name  genre  popularity   artist  acousticness  danceability  \
# 0       Halo  Dance          79  Beyoncé        0.2720         0.508
# 1       Halo    Pop          80  Beyoncé        0.2720         0.508
# 2       Halo    R&B          80  Beyoncé        0.2720         0.508
# 3  Partition  Dance          71  Beyoncé        0.0296         0.412
# 4  Partition    Pop          71  Beyoncé        0.0296         0.412
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 1       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 2       261640   0.720            0.0000   B    0.0563    -5.908  Minor
# 3       319467   0.441            0.0726   B    0.3060   -11.523  Minor
# 4       319467   0.441            0.0726   B    0.3060   -11.523  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.0628   79.983            4/4    0.472
# 1       0.0628   79.983            4/4    0.472
# 2       0.0628   79.983            4/4    0.472
# 3       0.2910  185.571            4/4    0.174
# 4       0.2910  185.571            4/4    0.174

# %%
df
# Out:
#            track_name             genre  popularity           artist  \
# 0                Halo             Dance          79          Beyoncé
# 1                Halo               Pop          80          Beyoncé
# 2                Halo               R&B          80          Beyoncé
# 3           Partition             Dance          71          Beyoncé
# 4           Partition               Pop          71          Beyoncé
# ...               ...               ...         ...              ...
# 34289   Wait for Love               R&B          43  Luther Vandross
# 34290   Wait for Love              Soul          43  Luther Vandross
# 34303  Safe and Sound       Alternative          51          Justice
# 34304  Safe and Sound             Dance          55          Justice
# 34306  Safe and Sound  Children’s Music          55          Justice
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0          0.272000         0.508       261640   0.720            0.0000   B
# 1          0.272000         0.508       261640   0.720            0.0000   B
# 2          0.272000         0.508       261640   0.720            0.0000   B
# 3          0.029600         0.412       319467   0.441            0.0726   B
# 4          0.029600         0.412       319467   0.441            0.0726   B
# ...             ...           ...          ...     ...               ...  ..
# 34289      0.418000         0.652       317747   0.419            0.0000  D#
# 34290      0.418000         0.652       317747   0.419            0.0000  D#
# 34303      0.000078         0.602       345304   0.793            0.1390  F#
# 34304      0.000078         0.602       345304   0.793            0.1390  F#
# 34306      0.000078         0.602       345304   0.793            0.1390  F#
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0        0.0563    -5.908  Minor       0.0628   79.983            4/4    0.472
# 1        0.0563    -5.908  Minor       0.0628   79.983            4/4    0.472
# 2        0.0563    -5.908  Minor       0.0628   79.983            4/4    0.472
# 3        0.3060   -11.523  Minor       0.2910  185.571            4/4    0.174
# 4        0.3060   -11.523  Minor       0.2910  185.571            4/4    0.174
# ...         ...       ...    ...          ...      ...            ...      ...
# 34289    0.2520    -9.843  Major       0.0930  124.187            4/4    0.496
# 34290    0.2520    -9.843  Major       0.0930  124.187            4/4    0.496
# 34303    0.0968    -5.198  Minor       0.0623  115.001            4/4    0.583
# 34304    0.0968    -5.198  Minor       0.0623  115.001            4/4    0.583
# 34306    0.0968    -5.198  Minor       0.0623  115.001            4/4    0.583
#
# [28069 rows x 17 columns]

# %%
plt.figure(dpi = 125)
sns.boxplot(data=df, x='genre', y='loudness', palette=['#64B6AC'], showfliers=False)
plt.xticks(rotation=90)
plt.title("Promedio de volumen de una canción según su género")
plt.xlabel("Género")
plt.ylabel("Volumen")
plt.show()
